# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from PIL import Image

# %%
#đường dẫn ảnh
my_path = 'C:/Users/ADMIN/Documents/TGMT_lop1/hinhanh/minion/minion.jpg'
#đọc ảnh và hiển thị
img = Image.open(my_path)
#display img
plt.imshow(img)

# %%
# Vẽ đồ thị cơ bản
x = [1, 2, 3, 4, 5]
y = [10, 15, 20, 25, 30]
plt.plot(x,y)
plt.show()

# %%
# Vẽ đồ thị cơ bản
x = [1, 2, 3, 4, 5]
y = [20, 15, 30, 25, 10]
plt.plot(x,y)
plt.show()

# %%
# Vẽ đồ thị cơ bản
x = [1, 2, 3, 4, 5]
y = [10, 15, 20, 25, 30]
plt.plot(x, y, color = 'red')
plt.show()

# %%
# Vẽ đồ thị cơ bản
x = [1, 2, 3, 4, 5]
y = [20, 15, 30, 25, 30]
plt.plot(x, y, color = 'red')
plt.show()

# %%
# Vẽ đồ thị cơ bản
x = [1, 2, 3, 4, 5]
y = [20, 15, 30, 25, 30]
plt.plot(x, y, color = 'red')# Màu sắc
plt.title('Ví dụ về vẽ biểu đồ')# Title
plt.show()# Hiển thị

# %%
# Vẽ đồ thị cơ bản
x = [1, 2, 3, 4, 5]
y = [20, 15, 30, 25, 30]
plt.plot(x, y, color = 'red')# Màu sắc
plt.title('Ví dụ về vẽ biểu đồ')# Title
plt.axis('off')#tắt hệ trục tọa độ
plt.show()# Hiển thị

# %%
# Vẽ trên hình ảnh
img = Image.open(my_path)
x = [500, 1000, 2000, 2400, 3300]
y = [2000, 1200, 1500, 1760, 500]

plt.imshow(img)#hiển thị hình ảnh
plt.plot(x, y, 'ro--')
plt.show()#show ra
